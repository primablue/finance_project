# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
import webbrowser
import requests
import lxml.html
import re
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager
# %matplotlib inline
import urllib.parse
import pandas as pd

# %%
MARKET_CODE_DICT = {
    'kospi': 'stockMkt',
    'kosdaq': 'kosdaqMkt',
    'konex': 'konexMkt'
}
DOWNLOAD_URL = 'kind.krx.co.kr/corpgeneral/corpList.do'
def download_stock_codes(market=None, delisted=False):
    params = {'method': 'download'}

    if market.lower() in MARKET_CODE_DICT:
        params['marketType'] = MARKET_CODE_DICT[market]

    if not delisted:
        params['searchType'] = 13

    params_string = urllib.parse.urlencode(params)
    request_url = urllib.parse.urlunsplit(['http', DOWNLOAD_URL, '', params_string, ''])

    df = pd.read_html(request_url, header=0)[0]
    df.종목코드 = df.종목코드.map('{:06d}'.format)

    return df
kosdaq_stocks = download_stock_codes('kospi')
kosdaq_stocks
# Out:
#              회사명    종목코드                                     업종  \
# 0          GS글로벌  001250                              상품 종합 도매업
# 1          HSD엔진  082740                          일반 목적용 기계 제조업
# 2          KG케미칼  001390                            기초 화학물질 제조업
# 3          LG이노텍  011070                               전자부품 제조업
# 4            OCI  010060                            기초 화학물질 제조업
# 5         SK네트웍스  001740                              기타 전문 도매업
# 6        SK이노베이션  096770                             석유 정제품 제조업
# 7            STX  011810                              상품 종합 도매업
# 8         WISCOM  024070                             플라스틱제품 제조업
# 9        갤럭시아에스엠  011420                               스포츠 서비스업
# 10        경동도시가스  267290                      연료용 가스 제조 및 배관공급업
# 11        경동인베스트  012320                                  석탄 광업
# 12          고려아연  010130                            1차 비철금속 제조업
# 13          고려제강  002240                              1차 철강 제조업
# 14          극동유화  014530                             석유 정제품 제조업
# 15         까뮤이앤씨  013700                                 건물 건설업
# 16          남양유업  003920                       낙농제품 및 식용빙과류 제조업
# 17         노루페인트  090350                            기타 화학제품 제조업
# 18        대림씨엔에스  004440               시멘트, 석회, 플라스터 및 그 제품 제조업
# 19          대영포장  014160                  골판지, 종이 상자 및 종이용기 제조업
# 20          대원제약  003220                                의약품 제조업
# 21         대유에이텍  002880                          자동차 신품 부품 제조업
# 22          대한해운  005880                                 해상 운송업
# 23          동남합성  023450                            기초 화학물질 제조업
# 24      동아쏘시오홀딩스  000640                                 기타 금융업
# 25            동양  001520               시멘트, 석회, 플라스터 및 그 제품 제조업
# 26        롯데손해보험  000400                                    보험업
# 27          롯데쇼핑  023530                                 종합 소매업
# 28           마니커  027740                     도축, 육류 가공 및 저장 처리업
# 29        모두투어리츠  204210                           부동산 임대 및 공급업
# ..           ...     ...                                    ...
# 759         케이씨텍  281820  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 760        케이탑리츠  145270                           부동산 임대 및 공급업
# 761        케이티앤지  033780                                 담배 제조업
# 762        크라운제과  264900                              기타 식품 제조업
# 763         테이팩스  055490                             플라스틱제품 제조업
# 764     포스코인터내셔널  047050                                 상품 중개업
# 765      폴루스바이오팜  007630                         통신 및 방송 장비 제조업
# 766           풍산  103140                            1차 비철금속 제조업
# 767          필룩스  033180                               전자부품 제조업
# 768       하나금융지주  086790                                 기타 금융업
# 769      하이골드12호  172580                               운송장비 임대업
# 778                          신현대             http://www.hmd.co.kr    울산광역시
# 779                     김영학, 이상준    http://www.hyundaipharm.co.kr     충청남도
# 780                          김성일             http://www.hcn.co.kr    서울특별시
# 781                          김경배       http://www.hyundai-wia.com     경상남도
# 782  정몽구, 정의선, 이원희, 하언태(각자 대표이사)           http://www.hyundai.com    서울특별시
# 783                          정몽혁     http://www.hyundaicorp.co.kr    서울특별시
# 784                          가삼현             http://www.hhi.co.kr    울산광역시
# 785                          이계영    http://www.hsenterprise.co.kr    부산광역시
# 786                          윤근창            http://www.fila.co.kr    서울특별시
# 787                          권중원       http://www.insurance.co.kr    서울특별시
# 788                          이윤재         http://www.heung-a.co.kr    서울특별시
#
# [789 rows x 9 columns]

# %%
stock = input("찾으시는 주식이름을 입력해주세요")
# Out:
# 찾으시는 주식이름을 입력해주세요현대자동차

# %%
startData = input("시작 날짜를 입력해주세요")
# Out:
# 시작 날짜를 입력해주세요20120101

# %%
columName = str(input("보고싶은 것?"))
# Out:
# 보고싶은 것?영업이익

# %%
stock_codeDF = kosdaq_stocks[(kosdaq_stocks.회사명 == stock)][['회사명','종목코드']]

stock_code = stock_codeDF.iloc[0]['종목코드']
stock_name = stock_codeDF.iloc[0]['회사명']

authKey = "92514dfc41e26715c7159127608020b866378caf"
companyCode = stock_code
startDate = startData

url = "http://dart.fss.or.kr/api/search.xml?auth="+authKey+"&crp_cd="+companyCode+"&start_dt="+startDate+"&bsn_tp=A001"+"&page_set=100"

resultXML = urlopen(url)
result = resultXML.read()

xmlsoup = BeautifulSoup(result , 'html.parser')

data = pd.DataFrame()
te = xmlsoup.findAll("list")

for i in te:
    temp = pd.DataFrame(([[i.crp_cls.string,i.crp_nm.string,i.crp_cd.string,i.rpt_nm.string,i.rcp_no.string,
                          i.flr_nm.string,i.rcp_dt.string,i.rmk.string]]),
                       columns = ["crp_cls","crp_nm","crp_cd","rpt_nm","rcp_no","flr_nm","rcp_dt","rmk"])
    data = pd.concat([data,temp])

data = data.reset_index(drop=True)
data
# Out:
#   crp_cls crp_nm  crp_cd                 rpt_nm          rcp_no flr_nm  \
# 0       Y  현대자동차  005380        사업보고서 (2018.12)  20190401004132  현대자동차
# 1       Y  현대자동차  005380        사업보고서 (2017.12)  20180402004162  현대자동차
# 2       Y  현대자동차  005380        사업보고서 (2016.12)  20170331004820  현대자동차
# 3       Y  현대자동차  005380        사업보고서 (2015.12)  20160330003641  현대자동차
# 4       Y  현대자동차  005380        사업보고서 (2014.12)  20150331003690  현대자동차
# 5       Y  현대자동차  005380        사업보고서 (2013.12)  20140331002965  현대자동차
# 6       Y  현대자동차  005380        사업보고서 (2012.12)  20130401002842  현대자동차
# 7       Y  현대자동차  005380  [첨부추가]사업보고서 (2011.12)  20120330002868  현대자동차
#
#      rcp_dt rmk
# 0  20190401   연
# 1  20180402   연
# 2  20170331   연
# 3  20160330   연
# 4  20150331   연
# 5  20140331   연
# 6  20130401   연
# 7  20120330   연

# %%
rcpNoList = data["rcp_no"].tolist()
rptNmList = data["rpt_nm"].tolist()
tempList = []
realList = []
tempIndex = 0
for i in range(0,len(rcpNoList)):
    url_user = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo="+rcpNoList[i]
    req = requests.get(url_user)
    tree = lxml.html.fromstring(req.text)
    ##질문 포인트
    onclick = tree.xpath('//*[@id="north"]/div[2]/ul/li[1]/a')[0].attrib['onclick']
    pattern = re.compile("^openPdfDownload\('\d+',\s*'(\d+)'\)")
    dcm_no = pattern.search(onclick).group(1)
    
    
    resp = "http://dart.fss.or.kr/report/viewer.do?rcpNo="+rcpNoList[i]+"&dcmNo="+dcm_no+"&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd"

    report = urlopen(resp)
    tempload = report.read()
  
    parsing = BeautifulSoup(tempload,'html.parser') 
   

    body = parsing.find("body")

    table = body.find_all("tbody")
    
    if(len(table) < 2):
        continue
    
    tmp2 = table[1]    

    tr = tmp2.select('tr')
    td = tmp2.select('tr > td')
    cellCount = int(len(td)/len(tr))
    
    for j in range(1,len(td)):
        if(j % cellCount == 0 ):
            tempA = (str(td[j]).split('>')[1].split('<')[0].replace("\xa0","").strip()) # .replace("           ",""))

            if(tempA == columName):
                tempIndex = j + 1
                tempList.append(str(td[tempIndex]).split('>')[1].split('<')[0])
                realList.append(rcpNoList[i])
                break;
    else:
        print(rptNmList[i]+" 문서에는 찾으시는 자료가 없습니다.")
    
#     date = (str(td[tempIndex-cellCount]).split('>')[1].split('<')[0])
# Out:
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004132&dcmNo=6612983&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20180402004162&dcmNo=6056588&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20170331004820&dcmNo=5541986&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20160330003641&dcmNo=5026676&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20150331003690&dcmNo=4560417&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20140331002965&dcmNo=4117654&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20130401002842&dcmNo=3713633&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20120330002868&dcmNo=3336431&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd

# %%
tempDataFrame = pd.DataFrame(tempList, columns = [columName])

for i in range(0,len(realList)):
    realList[i] = realList[i][0:4] 

tempDataFrame2 = pd.DataFrame(realList, columns = ["년도"])

resultDataFrame = pd.concat([tempDataFrame,tempDataFrame2], axis = 1)
resultDataFrame = resultDataFrame.sort_values(by = ["년도"],ascending = True)

fontprop = font_manager.FontProperties(fname="c:/windows/Fonts/malgun.ttf").get_name()
matplotlib.rc('font', family=fontprop)

x = list(resultDataFrame["년도"])
y = list(resultDataFrame[columName])

fig = plt.figure(figsize=(16,8))
plt.plot(x,y)
plt.plot(x,y, 'bo-', lw=2, label = columName)
plt.legend(loc=0)
plt.grid(True)
plt.xlabel("년도")
plt.ylabel(columName)
# Out:
# Text(0,0.5,'영업이익')

# %%
# user_num = int(input("몇 번째 보고서를 확인하겠습니까?"))
# url_user = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo="+data['rcp_no'][user_num]

# %%
# req = requests.get(url_user)
# tree = lxml.html.fromstring(req.text)
# onclick = tree.xpath('//*[@id="north"]/div[2]/ul/li[1]/a')[0].attrib['onclick']
# pattern = re.compile("^openPdfDownload\('\d+',\s*'(\d+)'\)")
# dcm_no = pattern.search(onclick).group(1)
# ##질문 포인트

# resp = "http://dart.fss.or.kr/report/viewer.do?rcpNo="+data['rcp_no'][user_num]+"&dcmNo="+dcm_no+"&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd"

# report = urlopen(resp)
# tempload = report.read()

# parsing = BeautifulSoup(tempload,'html.parser') 

# body = parsing.find("body")

# table = body.find_all("tbody")

# tmp2 = table[1]    

# tr = tmp2.select('tr')
# td = tmp2.select('tr > td')
# td

# %%
tr
# Out:
# [<tr>
#  <td height="20" valign="TOP" width="139">[유동자산]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">   11,792,456</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">10,301,034</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">8,921,168</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">8,043,005</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">9,003,365</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139"> ㆍ당좌자산</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">10,407,958</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">8,492,004</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">7,472,194</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">6,823,419</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">7,995,279</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139"> ㆍ재고자산</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">1,384,498</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,809,030</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,448,974</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,219,586</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,008,086</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">[비유동자산]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">23,653,679</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">21,866,695</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">20,665,761</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">18,386,953</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">17,657,961</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139"> ㆍ투자자산</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">11,624,304</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">10,076,837</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">9,079,373</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">7,148,382</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">6,575,281</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139"> ㆍ유형자산</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">9,726,299</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">9,753,801</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">9,721,065</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">9,465,474</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">8,945,562</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139"> ㆍ무형자산</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">1,840,055</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,605,862</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,381,124</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,118,597</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">920,395</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139"> ㆍ기타비유동자산</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">463,021</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">430,195</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">484,199</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">654,500</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,216,723</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">자산총계</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">35,446,135</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">32,167,729</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">29,586,929</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">26,429,958</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">26,661,326</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">[유동부채]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">8,923,674</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">7,915,089</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">7,055,992</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">6,333,745</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">7,616,645</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">[비유동부채]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">4,493,438</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">4,600,349</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">4,328,306</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">4,045,385</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">3,991,717</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">부채총계</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">13,417,112</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">12,515,438</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">11,384,298</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">10,379,130</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">11,608,362</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">[자본금]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">1,488,993</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,488,993</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,486,980</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,484,942</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,482,905</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">[자본잉여금]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">5,806,189</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,851,776</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,752,060</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,409,005</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,391,620</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">[자본조정]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">(743,909)</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">(719,685)</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">(718,855)</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">(706,979)</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">(721,882)</td>
#  </tr>, <tr>
#  <td height="43" valign="TOP" width="139">[기타포괄손익<br/> 누계액]</td>
#  <td align="RIGHT" height="43" width="101">486,638</td>
#  <td align="RIGHT" height="43" width="90">612,153</td>
#  <td align="RIGHT" height="43" width="90">198,012</td>
#  <td align="RIGHT" height="43" width="90">(226,605)</td>
#  <td align="RIGHT" height="43" width="90">(24,216)</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">[이익잉여금]</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">14,991,112</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">12,419,054</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">11,484,434</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">10,090,465</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">8,924,537</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">자본총계</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">22,029,023</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">19,652,291</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">18,202,631</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">16,050,828</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">15,052,964</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">매출액</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">31,859,327</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">32,189,786</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">30,619,671</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">27,527,467</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">27,602,727</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">영업이익</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">2,234,962</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,877,218</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,945,523</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,426,547</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,603,133</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">당기순이익</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">2,961,509</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,447,904</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,682,419</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">1,526,063</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">2,348,721</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">기본주당이익</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">10,890</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,325</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">6,207</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,636</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">10,652</td>
#  </tr>, <tr>
#  <td height="20" valign="TOP" width="139">희석주당이익</td>
#  <td align="RIGHT" height="20" valign="TOP" width="101">10,890</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,319</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">6,192</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">5,614</td>
#  <td align="RIGHT" height="20" valign="TOP" width="90">10,599</td>
#  </tr>]
